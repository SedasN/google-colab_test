# %% [markdown]
# <a href="https://colab.research.google.com/github/SedasN/google-colab_test/blob/main/second_book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# df = pd.read_csv('100 Sales Records.csv')

# %%
s = pd.Series(df.values.flatten())

# %%
s
# Out:
# 0       Australia and Oceania
# 1                      Tuvalu
# 2                   Baby Food
# 3                     Offline
# 4                           H
#                 ...
# 1395                   668.27
# 1396                   502.54
# 1397               3586605.09
# 1398               2697132.18
# 1399                889472.91
# Length: 1400, dtype: object

# %%
total_sales = df.sum()
print(total_sales)
# Out:
# Region            Australia and OceaniaCentral America and the C...
# Country           TuvaluGrenadaRussiaSao Tome and PrincipeRwanda...
# Item Type         Baby FoodCerealOffice SuppliesFruitsOffice Sup...
# Sales Channel     OfflineOnlineOfflineOnlineOfflineOnlineOffline...
# Order Priority    HCLCLCMHMHHHLHCMMCLLLHLHLHMLCLMCCHMLLMLMHMHHHH...
# Order Date        5/28/20108/22/20125/2/20146/20/20142/1/20132/4...
# Order ID                                                55502041236
# Ship Date         6/27/20109/15/20125/8/20147/5/20142/6/20132/21...
# Units Sold                                                   512871
# Unit Price                                                 27676.13
# Unit Cost                                                   19104.8
# Total Revenue                                          137348768.31
# Total Cost                                              93180569.91
# Total Profit                                             44168198.4
# dtype: object

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e47e86c5-ed30-45c3-bdc2-b0cb5b7aa9bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e47e86c5-ed30-45c3-bdc2-b0cb5b7aa9bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(uploaded)
# Out:
# {'db (1).json': b'[\r\n  {\r\n    "sql_id": "Muhammadrizo_Shokiri_MwW5UVb6Y",\r\n    "id": "68",\r\n    "name_tj": "\xd0\x9c\xd1\x83\xd2\xb3\xd0\xb0\xd0\xbc\xd0\xbc\xd0\xb0\xd0\xb4\xd1\x80\xd0\xb8\xd0\xb7\xd0\xbe",\r\n    "last_name_tj": "\xd0\xa8\xd0\xbe\xd0\xba\xd0\xb8\xd1\x80\xd3\xa3",\r\n    "name_en": "Muhammadrizo",\r\n    "last_name_en": "Shokiri",\r\n    "gender": "Male",\r\n    "student_group": "\xec\xb4\x88\xea\xb8\x89 2B-1",\r\n    "time_lesson": "14:00",\r\n    "topik": "2 lvl",\r\n    "payment": "Certificate",\r\n    "student_status": "registered",\r\n    "exam": "No",\r\n    "agreement": "Agree",\r\n    "book": "Own Book"\r\n  },\r\n  {\r\n    "sql_id": "Zuhro_Hamidova_YtP7KLf9A",\r\n    "id": "69",\r\n    "name_tj": "\xd0\x97\xd1\x83\xd2\xb3\xd1\x80\xd0\xbe",\r\n    "last_name_tj": "\xd2\xb2\xd0\xb0\xd0\xbc\xd0\xb8\xd0\xb4\xd0\xbe\xd0\xb2\xd0\xb0",\r\n    "name_en": "Zuhro",\r\n    "last_name_en": "Hamidova",\r\n    "gender": "Female",\r\n    "student_group": "\xec\xb4
# ...

# %%
a = pd.Series(uploaded)

# %%
a
# Out:
# db (1).json    b'[\r\n  {\r\n    "sql_id": "Muhammadrizo_Shok...
# dtype: object

# %%
import json

# %%
import json

# читаем однострочный JSON
with open('db.json', 'r') as f:
    data = json.load(f)

# записываем красиво
with open('db_pretty.json', 'w') as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

print("Файл db_pretty.json отформатирован.")
# Out:
# Файл db_pretty.json отформатирован.

# %%
print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "sql_id": "Muhammadrizo_Shokiri_MwW5UVb6Y",
#         "id": "68",
#         "name_tj": "Муҳаммадризо",
#         "last_name_tj": "Шокирӣ",
#         "name_en": "Muhammadrizo",
#         "last_name_en": "Shokiri",
#         "gender": "Male",
#         "student_group": "초급 2B-1",
#         "time_lesson": "14:00",
#         "topik": "2 lvl",
#         "payment": "Certificate",
#         "student_status": "registered",
#         "exam": "No",
#         "agreement": "Agree",
#         "book": "Own Book"
#     },
#     {
#         "sql_id": "Zuhro_Hamidova_YtP7KLf9A",
#         "id": "69",
#         "name_tj": "Зуҳро",
#         "last_name_tj": "Ҳамидова",
#         "name_en": "Zuhro",
#         "last_name_en": "Hamidova",
#         "gender": "Female",
#         "student_group": "초급 2B-1",
#         "time_lesson": "14:00",
#         "topik": "1 lvl",
#         "payment": "Certificate",
#         "student_status": "registered",
#         "exam": "No",
# ...

# %%
print(data[13]['topik'])
# Out:
# 1 lvl

# %%
df = pd.read_csv('StudentPerformanceFactors.csv')

# %%
print(df)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df_sorted = df.sort_values(by='Exam_Score', ascending=True)
display(df_sorted.head())
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 1101              3          62               Medium                 Low
# 5507              5          65                  Low                High
# 5907              3          60               Medium                 Low
# 3543             14          67                  Low                 Low
# 5719              9          64               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 1101                         No            6               67
# 5507                         No            7               71
# 5907                        Yes            6               78
# 3543                        Yes            7               66
# 5719                        Yes           10               68
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 1101           Medium             Yes                  1           Low
# ...

# %%
names_en = [student['name_en'] for student in data]
print(names_en)
# Out:
# ['Muhammadrizo', 'Zuhro', 'Farhod', 'Madina', 'Jamshed', 'Nigina', 'Sherzod', 'Mavluda', 'Ismoil', 'Zarina', 'Rustam', 'Dilnoza', 'Abdurahmon', 'Malika']

# %% [markdown]
# If you want to extract the names in Tajik, you can use `name_tj` instead:

# %%
names_tj = [student['name_tj'] for student in data]
print(names_tj)
# Out:
# ['Муҳаммадризо', 'Зуҳро', 'Фарҳод', 'Мадина', 'Ҷамшед', 'Нигина', 'Шерзод', 'Мавлуда', 'Исмоил', 'Зарина', 'Рустам', 'Дилноза', 'Абдураҳмон', 'Малика']

# %%
male_students = [student for student in data if student['gender'] == 'Male']
male_names = [student['name_en'] for student in male_students]
print(male_names)
# Out:
# ['Muhammadrizo', 'Farhod', 'Jamshed', 'Sherzod', 'Ismoil', 'Rustam', 'Abdurahmon']

# %%
average_nums = nums.mean()
print(f"The arithmetic mean of nums is: {average_nums}")
# Out:
# The arithmetic mean of nums is: 6095.0

# %%
b = [1000, 435, 246, 2525, 6787, 25577]

# %%
nums = pd.Series(b)

# %%
nums.sum()
# Out:
# np.int64(36570)

# %%
nums.max()
# Out:
# 25577

# %%
nums.min()
# Out:
# 246

# %%
pd.Series([1,2,5]).product()
# Out:
# np.int64(10)

# %%
d = [10, 20, 30, 40]
a = pd.Series(d)

# %%
a.mean()
# Out:
# np.float64(25.0)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.lt(25)
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
a.gt(10)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# dtype: bool

# %%
a.eq(10)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
a.ne(10)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# dtype: bool

# %%
a.ge(23)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
a.le(9)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
a.abs()
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
