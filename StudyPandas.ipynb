# %% [markdown]
# <a href="https://colab.research.google.com/github/SedasN/google-colab_test/blob/main/StudyPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from random import randint

# %%
numbers = [randint(-50, 50) for _ in range(50)]

# %%
a = pd.Series(numbers)

# %%
a
# Out:
# 0    -38
# 1      4
# 2    -41
# 3     -5
# 4    -38
# 5     22
# 6      0
# 7    -28
# 8    -17
# 9    -22
# 10   -11
# 11     8
# 12    29
# 13   -13
# 14    -4
# 15    34
# 16   -30
# 17    22
# 18   -14
# 19   -40
# 20    15
# 21    30
# 22   -34
# 23   -12
# 24   -35
# 25    19
# 26    19
# 27    -3
# 28    18
# 29    30
# 30    28
# 31    14
# 32    -1
# 33   -46
# 34    38
# 35    -8
# 36   -49
# 37   -21
# 38    32
# 39    30
# 40   -34
# 41     7
# 42   -43
# 43   -23
# 44    47
# 45    18
# 46     6
# 47    36
# 48    15
# 49    -8
# dtype: int64

# %%
a.tail()
# Out:
# 45    18
# 46     6
# 47    36
# 48    15
# 49    -8
# dtype: int64

# %%
a.take([])
# Out:
# Series([], dtype: int64)

# %%
list(range(5,10))
# Out:
# [5, 6, 7, 8, 9]

# %%
a.take(range(5, 10, 1))
# Out:
# 5    22
# 6     0
# 7   -28
# 8   -17
# 9   -22
# dtype: int64

# %%
len(a)
# Out:
# 50

# %%
a[4:10]
# Out:
# 4   -38
# 5    22
# 6     0
# 7   -28
# 8   -17
# 9   -22
# dtype: int64
